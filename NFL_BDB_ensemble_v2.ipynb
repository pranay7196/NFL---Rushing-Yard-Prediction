# %% [markdown]
# # About this kernel
#
# Mostly copied from bestpredict's kernel [Location EDA 8eb410][1]. I have applied the random forest (RF) regressor proposed in Dimension's kernel [[NFL] - [001]- [Feature selection]][2]. Let's see whether the reduced feature dimension will result in LB score improvement (V1-V3) and whether blending RF and neural network (NN) will improve the LB score (V4+). Please correct me if you have found any mistake. Thank you very much.
#
# ## Changelog
# * **V5**: Try larger NN and elu activation.
# * **V4**: Since there is no improvement on LB score by discarding the original features, I try blending random forest and NN.
# * **V3**: Try threshold 0.2* mean
# * **V2**: Try threshold 0.5* mean
# * **V1**: Add feature selection based on the feature importance from a prefitted random forest regressor
#
# [1]: https://www.kaggle.com/bestpredict/location-eda-8eb410
# [2]: https://www.kaggle.com/coolcoder22/nfl-001-feature-selection

# %%
import os
TRAIN_ABLE_FALSE=True
if TRAIN_ABLE_FALSE:
    os.environ['CUDA_VISIBLE_DEVICES'] = "1"
import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization,LeakyReLU,PReLU,ELU,ThresholdedReLU,Concatenate
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime
import warnings
warnings.filterwarnings('ignore')

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nfl-big-data-bowl-2020/train.csv
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/test.csv.encrypted
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/__init__.py
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/competition.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/sample_submission.csv.encrypted

# %%
# train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
if TRAIN_OFFLINE:
    train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})
else:
    train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
#train = pd.DataFrame(train.head(66000))

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
    # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
    # train["Week_ob"] = train["Week"].astype("object")
    # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %% [markdown]
# ## Functions for anchoring offense moving left from {0,0}

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y','PlayerWeight']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY', 'RusherWeight']
        
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        rusher['momentum'] = rusher['RusherA']*rusher['RusherWeight']
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA', 'RusherX', 'RusherY','RusherWeight','v_horizontal', 'v_vertical','momentum']
        
        return rusher


    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1])) 
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        add_new_feas.append('TimeDelta')
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append('GameWeather_dense')
#         ## Rusher
#         train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
#         train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
#         temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
#         train = train.merge(temp, on = "PlayId")
#         train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

        ## dense -> categorical
#         train["Quarter_ob"] = train["Quarter"].astype("object")
#         train["Down_ob"] = train["Down"].astype("object")
#         train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
#         train["YardLine_ob"] = train["YardLine"].astype("object")
        # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
        # train["Week_ob"] = train["Week"].astype("object")
        # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
        
        Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
        df['Turf'] = df['Turf'].map(Turf)
        df['Turf_flag'] = df['Turf'].apply(lambda x: 1 if x == 'Artificial' else 0)
        add_new_feas.append("Turf_flag")
        
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Distance','DefendersInTheBox']].drop_duplicates()
#         static_features['DefendersInTheBox'] = static_features['DefendersInTheBox'].fillna(np.mean(static_features['DefendersInTheBox']))
        static_features.fillna(-999,inplace=True)
    
        return static_features
    
    def cat_features(df):
        
        cat = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','OffenseFormation','Quarter','Down']]
        cat['OffenseFormation'] = cat['OffenseFormation'].fillna('EMPTY')
        replace_values = {'' : 'EMPTY', 'WILDCAT' : 'EMPTY', 'ACE' : 'EMPTY'}                                                                                          
        cat = cat.replace({"OffenseFormation": replace_values})
        
        cat["Quarter_ob"] = cat["Quarter"].astype("object")
        cat["Down_ob"] = cat["Down"].astype("object")
        
        cat = pd.concat([cat,pd.get_dummies(cat['OffenseFormation'], prefix='OffenseFormation')],axis=1)
        cat = pd.concat([cat,pd.get_dummies(cat['Quarter_ob'], prefix='Quarter_ob')],axis=1)
        cat = pd.concat([cat,pd.get_dummies(cat['Down_ob'], prefix='Down_ob')],axis=1)
        
        cat.drop(['OffenseFormation','Quarter','Down','Down_ob','Quarter_ob'], axis = 1, inplace = True)
        
        return cat


    def combine_features(relative_to_back, defense,rushing, static,cat, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,cat,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    cat_feats = cat_features(df)
    basetable = combine_features(rel_back, def_feats,rush_feats,static_feats,cat_feats, deploy=deploy)

    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# CPU times: user 4min 43s, sys: 4.56 s, total: 4min 47s
# Wall time: 4min 48s

# %%
train_basetable.shape
# Out:
# (23171, 57)

# %%
train_basetable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23171 entries, 0 to 23170
# Data columns (total 57 columns):
# GameId                         23171 non-null int64
# PlayId                         23171 non-null int64
# back_from_scrimmage            23171 non-null float64
# back_oriented_down_field       23171 non-null int64
# back_moving_down_field         23171 non-null int64
# min_dist                       23171 non-null float64
# max_dist                       23171 non-null float64
# mean_dist                      23171 non-null float64
# std_dist                       23171 non-null float64
# def_min_dist                   23171 non-null float64
# def_max_dist                   23171 non-null float64
# def_mean_dist                  23171 non-null float64
# def_std_dist                   23171 non-null float64
# RusherDir                      23171 non-null float64
# RusherS                        23171 non-null float64
# RusherA                        23171 non-null float64
# RusherX                        23171 non-null float64
# RusherY                        23171 non-null float64
# RusherWeight                   23171 non-null int64
# v_horizontal                   23171 non-null float64
# v_vertical                     23171 non-null float64
# momentum                       23171 non-null float64
# PlayerHeight_dense             23171 non-null int64
# TimeDelta                      23171 non-null float64
# PlayerAge                      23171 non-null float64
# WindSpeed_dense                23171 non-null float64
# GameWeather_dense              23171 non-null float64
# Dir_sin                        23171 non-null float64
# Dir_cos                        23171 non-null float64
# diffScoreBeforePlay            23171 non-null int64
# Turf_flag                      23171 non-null int64
# X                              23171 non-null float64
# Y                              23171 non-null float64
# S                              23171 non-null float64
# A                              23171 non-null float64
# Dis                            23171 non-null float64
# Orientation                    23171 non-null float64
# Dir                            23171 non-null float64
# YardLine                       23171 non-null float64
# Distance                       23171 non-null int64
# DefendersInTheBox              23171 non-null float64
# OffenseFormation_EMPTY         23171 non-null uint8
# OffenseFormation_I_FORM        23171 non-null uint8
# OffenseFormation_JUMBO         23171 non-null uint8
# OffenseFormation_PISTOL        23171 non-null uint8
# OffenseFormation_SHOTGUN       23171 non-null uint8
# OffenseFormation_SINGLEBACK    23171 non-null uint8
# Quarter_ob_1                   23171 non-null uint8
# Quarter_ob_2                   23171 non-null uint8
# Quarter_ob_3                   23171 non-null uint8
# Quarter_ob_4                   23171 non-null uint8
# Quarter_ob_5                   23171 non-null uint8
# Down_ob_1                      23171 non-null uint8
# Down_ob_2                      23171 non-null uint8
# Down_ob_3                      23171 non-null uint8
# Down_ob_4                      23171 non-null uint8
# Yards                          23171 non-null int64
# dtypes: float64(32), int64(10), uint8(15)
# memory usage: 7.9 MB

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# # Let's build NN and Random Forest Regressor

# %% [markdown]
# Below class Metric based entirely on: https://www.kaggle.com/kingychiu/keras-nn-starter-crps-early-stopping
# <br></br>
# Below early stopping entirely based on: https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/112868#latest-656533

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
from keras.optimizers import Adam
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, Callback
import codecs
from keras.utils import to_categorical
from sklearn.metrics import f1_score

class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
# Calculate CRPS score
def crps_score(y_prediction, y_valid, shape=X.shape[0]):
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_prediction, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * shape)
    crps = np.round(val_s, 6)
    
    return crps

# %% [markdown]
# ## NN

# %%
def get_nn(x_tr, y_tr, x_val, y_val, shape):
    K.clear_session()
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(2048, input_dim=X.shape[1], activation='elu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation='elu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='elu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='elu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model
    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz

    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=200, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    crps = crps_score(y_pred, y_valid, shape=shape)

    return model,crps

# %% [markdown]
# ## RF

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# increase the n_estimators (50 -> 64) to see if this improves CV
def get_rf(x_tr, y_tr, x_val, y_val, shape):
    model = RandomForestRegressor(bootstrap=False, max_features=0.3, min_samples_leaf=15, 
                                  min_samples_split=8, n_estimators=64, n_jobs=-1, random_state=42)
    model.fit(x_tr, y_tr)
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    crps = crps_score(y_pred, y_valid, shape=shape)
    
    return model, crps

# %% [markdown]
# ## Training

# %%
from sklearn.model_selection import train_test_split, KFold
import time

loop = 1
fold = 2

oof_nn = np.zeros([loop, y.shape[0], y.shape[1]])
oof_rf = np.zeros([loop, y.shape[0], y.shape[1]])

models_nn = []
crps_csv_nn = []
models_rf = []
crps_csv_rf = []

s_time = time.time()

for k in range(loop):
    kfold = KFold(fold, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print(f'Loop {k+1}/{loop}' + f' Fold {k_fold+1}/{fold}')
        print("-----------")
        tr_x, tr_y = X[tr_inds], y[tr_inds]
        val_x, val_y = X[val_inds], y[val_inds]
        
        # Train NN
        nn, crps_nn = get_nn(tr_x, tr_y, val_x, val_y, shape=val_x.shape[0])
        models_nn.append(nn)
        print("the %d fold crps (NN) is %f"%((k_fold+1), crps_nn))
        crps_csv_nn.append(crps_nn)
        
        # Train RF
        rf, crps_rf = get_rf(tr_x, tr_y, val_x, val_y, shape=val_x.shape[0])
        models_rf.append(rf)
        print("the %d fold crps (RF) is %f"%((k_fold+1), crps_rf))
        crps_csv_rf.append(crps_rf)
        
        #Predict OOF
        oof_nn[k, val_inds, :] = nn.predict(val_x)
        oof_rf[k, val_inds, :] = rf.predict(val_x)
# Out:
# -----------
# Loop 1/1 Fold 1/2
# -----------
# validation shape 2
# Epoch 1/200
# 11585/11585 [==============================] - 6s 544us/step - loss: 5.5657
#
# Epoch 00001: CRPS_score_val improved from inf to 0.05432, saving model to best_model.h5
# Epoch 2/200
# 11585/11585 [==============================] - 5s 436us/step - loss: 5.0911
#
# Epoch 00002: CRPS_score_val improved from 0.05432 to 0.03262, saving model to best_model.h5
# Epoch 3/200
# 11585/11585 [==============================] - 5s 445us/step - loss: 4.7890
#
# Epoch 00003: CRPS_score_val improved from 0.03262 to 0.02867, saving model to best_model.h5
# Epoch 4/200
# 11585/11585 [==============================] - 5s 447us/step - loss: 4.5760
#
# Epoch 00004: CRPS_score_val improved from 0.02867 to 0.02668, saving model to best_model.h5
# Epoch 5/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 4.3808
#
# Epoch 00005: CRPS_score_val improved from 0.02668 to 0.02418, saving model to best_model.h5
# Epoch 6/200
# 11585/11585 [==============================] - 5s 447us/step - loss: 4.1767
#
# Epoch 00006: CRPS_score_val improved from 0.02418 to 0.02124, saving model to best_model.h5
# Epoch 7/200
# 11585/11585 [==============================] - 5s 446us/step - loss: 3.9717
#
# Epoch 00007: CRPS_score_val improved from 0.02124 to 0.01945, saving model to best_model.h5
# Epoch 8/200
# 11585/11585 [==============================] - 5s 448us/step - loss: 3.7498
#
# Epoch 00008: CRPS_score_val improved from 0.01945 to 0.01745, saving model to best_model.h5
# Epoch 9/200
# 11585/11585 [==============================] - 5s 441us/step - loss: 3.5149
#
# Epoch 00009: CRPS_score_val improved from 0.01745 to 0.01597, saving model to best_model.h5
# Epoch 10/200
# 11585/11585 [==============================] - 5s 438us/step - loss: 3.3267
#
# Epoch 00010: CRPS_score_val improved from 0.01597 to 0.01506, saving model to best_model.h5
# Epoch 11/200
# 11585/11585 [==============================] - 5s 440us/step - loss: 3.1701
#
# Epoch 00011: CRPS_score_val improved from 0.01506 to 0.01473, saving model to best_model.h5
# Epoch 12/200
# 11585/11585 [==============================] - 5s 440us/step - loss: 3.0471
#
# Epoch 00012: CRPS_score_val improved from 0.01473 to 0.01405, saving model to best_model.h5
# Epoch 13/200
# 11585/11585 [==============================] - 5s 444us/step - loss: 2.9685
#
# Epoch 00013: CRPS_score_val improved from 0.01405 to 0.01363, saving model to best_model.h5
# Epoch 14/200
# 11585/11585 [==============================] - 5s 442us/step - loss: 2.9246
#
# Epoch 00014: CRPS_score_val improved from 0.01363 to 0.01348, saving model to best_model.h5
# Epoch 15/200
# 11585/11585 [==============================] - 5s 434us/step - loss: 2.8699
#
# Epoch 00015: CRPS_score_val improved from 0.01348 to 0.01330, saving model to best_model.h5
# Epoch 16/200
# 11585/11585 [==============================] - 5s 444us/step - loss: 2.8436
#
# Epoch 00016: CRPS_score_val improved from 0.01330 to 0.01321, saving model to best_model.h5
# Epoch 17/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.8145
#
# Epoch 00017: CRPS_score_val improved from 0.01321 to 0.01321, saving model to best_model.h5
# Epoch 18/200
# 11585/11585 [==============================] - 5s 441us/step - loss: 2.7967
#
# Epoch 00018: CRPS_score_val improved from 0.01321 to 0.01310, saving model to best_model.h5
# Epoch 19/200
# 11585/11585 [==============================] - 5s 438us/step - loss: 2.7836
#
# Epoch 00019: CRPS_score_val improved from 0.01310 to 0.01306, saving model to best_model.h5
# Epoch 20/200
# 11585/11585 [==============================] - 5s 429us/step - loss: 2.7748
#
# Epoch 00020: CRPS_score_val improved from 0.01306 to 0.01304, saving model to best_model.h5
# Epoch 21/200
# 11585/11585 [==============================] - 5s 430us/step - loss: 2.7561
#
# Epoch 00021: CRPS_score_val improved from 0.01304 to 0.01302, saving model to best_model.h5
# Epoch 22/200
# 11585/11585 [==============================] - 5s 431us/step - loss: 2.7440
#
# Epoch 00022: CRPS_score_val improved from 0.01302 to 0.01297, saving model to best_model.h5
# Epoch 23/200
# 11585/11585 [==============================] - 5s 430us/step - loss: 2.7345
#
# Epoch 00023: CRPS_score_val improved from 0.01297 to 0.01296, saving model to best_model.h5
# Epoch 24/200
# 11585/11585 [==============================] - 5s 439us/step - loss: 2.7248
#
# Epoch 00024: CRPS_score_val did not improve from 0.01296
# Epoch 25/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.7138
#
# Epoch 00025: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 26/200
# 11585/11585 [==============================] - 5s 424us/step - loss: 2.7105
#
# Epoch 00026: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 27/200
# 11585/11585 [==============================] - 5s 433us/step - loss: 2.7035
#
# Epoch 00027: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 28/200
# 11585/11585 [==============================] - 5s 430us/step - loss: 2.6917
#
# Epoch 00028: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 29/200
# 11585/11585 [==============================] - 5s 432us/step - loss: 2.7020
#
# Epoch 00029: CRPS_score_val did not improve from 0.01292
# Epoch 30/200
# 11585/11585 [==============================] - 5s 439us/step - loss: 2.6883
#
# Epoch 00030: CRPS_score_val improved from 0.01292 to 0.01290, saving model to best_model.h5
# Epoch 31/200
# 11585/11585 [==============================] - 6s 506us/step - loss: 2.6856
#
# Epoch 00031: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 32/200
# 11585/11585 [==============================] - 5s 446us/step - loss: 2.6828
#
# Epoch 00032: CRPS_score_val did not improve from 0.01290
# Epoch 33/200
# 11585/11585 [==============================] - 5s 436us/step - loss: 2.6769
#
# Epoch 00033: CRPS_score_val did not improve from 0.01290
# Epoch 34/200
# 11585/11585 [==============================] - 5s 444us/step - loss: 2.6677
#
# Epoch 00034: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 35/200
# 11585/11585 [==============================] - 5s 438us/step - loss: 2.6648
#
# Epoch 00035: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 36/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.6676
#
# Epoch 00036: CRPS_score_val did not improve from 0.01289
# Epoch 37/200
# 11585/11585 [==============================] - 5s 457us/step - loss: 2.6568
#
# Epoch 00037: CRPS_score_val did not improve from 0.01289
# Epoch 38/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.6488
#
# Epoch 00038: CRPS_score_val did not improve from 0.01289
# Epoch 39/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.6549
#
# Epoch 00039: CRPS_score_val did not improve from 0.01289
# Epoch 40/200
# 11585/11585 [==============================] - 5s 428us/step - loss: 2.6507
#
# Epoch 00040: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 41/200
# 11585/11585 [==============================] - 5s 435us/step - loss: 2.6351
#
# Epoch 00041: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 42/200
# 11585/11585 [==============================] - 5s 437us/step - loss: 2.6343
#
# Epoch 00042: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 43/200
# 11585/11585 [==============================] - 5s 446us/step - loss: 2.6366
#
# Epoch 00043: CRPS_score_val did not improve from 0.01286
# Epoch 44/200
# 11585/11585 [==============================] - 5s 432us/step - loss: 2.6347
#
# Epoch 00044: CRPS_score_val did not improve from 0.01286
# Epoch 45/200
# 11585/11585 [==============================] - 5s 444us/step - loss: 2.6252
#
# Epoch 00045: CRPS_score_val did not improve from 0.01286
# Epoch 46/200
# 11585/11585 [==============================] - 5s 442us/step - loss: 2.6260
#
# Epoch 00046: CRPS_score_val did not improve from 0.01286
# Epoch 47/200
# 11585/11585 [==============================] - 5s 451us/step - loss: 2.6192
#
# Epoch 00047: CRPS_score_val did not improve from 0.01286
# Epoch 48/200
# 11585/11585 [==============================] - 5s 436us/step - loss: 2.6179
#
# Epoch 00048: CRPS_score_val did not improve from 0.01286
# Epoch 49/200
# 11585/11585 [==============================] - 5s 443us/step - loss: 2.6154
#
# Epoch 00049: CRPS_score_val did not improve from 0.01286
# Epoch 50/200
# 11585/11585 [==============================] - 5s 448us/step - loss: 2.6138
#
# Epoch 00050: CRPS_score_val did not improve from 0.01286
# Epoch 51/200
# 11585/11585 [==============================] - 5s 440us/step - loss: 2.6071
#
# Epoch 00051: CRPS_score_val did not improve from 0.01286
# Epoch 52/200
# 11585/11585 [==============================] - 5s 435us/step - loss: 2.6064
# Restoring model weights from the end of the best epoch
#
# Epoch 00052: CRPS_score_val did not improve from 0.01286
# Epoch 00052: early stopping
# the 1 fold crps (NN) is 0.012864
# the 1 fold crps (RF) is 0.012954
# -----------
# Loop 1/1 Fold 2/2
# -----------
# validation shape 2
# Epoch 1/200
# 11586/11586 [==============================] - 6s 522us/step - loss: 5.5667
#
# Epoch 00001: CRPS_score_val improved from inf to 0.05450, saving model to best_model.h5
# Epoch 2/200
# 11586/11586 [==============================] - 5s 441us/step - loss: 5.0808
#
# Epoch 00002: CRPS_score_val improved from 0.05450 to 0.03438, saving model to best_model.h5
# Epoch 3/200
# 11586/11586 [==============================] - 5s 439us/step - loss: 4.7781
#
# Epoch 00003: CRPS_score_val improved from 0.03438 to 0.02964, saving model to best_model.h5
# Epoch 4/200
# 11586/11586 [==============================] - 5s 439us/step - loss: 4.5745
#
# Epoch 00004: CRPS_score_val improved from 0.02964 to 0.02659, saving model to best_model.h5
# Epoch 5/200
# 11586/11586 [==============================] - 5s 443us/step - loss: 4.3559
#
# Epoch 00005: CRPS_score_val improved from 0.02659 to 0.02377, saving model to best_model.h5
# Epoch 6/200
# 11586/11586 [==============================] - 5s 442us/step - loss: 4.1875
#
# Epoch 00006: CRPS_score_val improved from 0.02377 to 0.02145, saving model to best_model.h5
# Epoch 7/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 3.9855
#
# Epoch 00007: CRPS_score_val improved from 0.02145 to 0.01933, saving model to best_model.h5
# Epoch 8/200
# 11586/11586 [==============================] - 5s 450us/step - loss: 3.7652
#
# Epoch 00008: CRPS_score_val improved from 0.01933 to 0.01798, saving model to best_model.h5
# Epoch 9/200
# 11586/11586 [==============================] - 5s 438us/step - loss: 3.5496
#
# Epoch 00009: CRPS_score_val improved from 0.01798 to 0.01634, saving model to best_model.h5
# Epoch 10/200
# 11586/11586 [==============================] - 5s 439us/step - loss: 3.3428
#
# Epoch 00010: CRPS_score_val improved from 0.01634 to 0.01546, saving model to best_model.h5
# Epoch 11/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 3.1698
#
# Epoch 00011: CRPS_score_val improved from 0.01546 to 0.01476, saving model to best_model.h5
# Epoch 12/200
# 11586/11586 [==============================] - 6s 478us/step - loss: 3.0491
#
# Epoch 00012: CRPS_score_val improved from 0.01476 to 0.01397, saving model to best_model.h5
# Epoch 13/200
# 11586/11586 [==============================] - 5s 440us/step - loss: 2.9668
#
# Epoch 00013: CRPS_score_val improved from 0.01397 to 0.01364, saving model to best_model.h5
# Epoch 14/200
# 11586/11586 [==============================] - 5s 441us/step - loss: 2.9085
#
# Epoch 00014: CRPS_score_val improved from 0.01364 to 0.01341, saving model to best_model.h5
# Epoch 15/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.8829
#
# Epoch 00015: CRPS_score_val improved from 0.01341 to 0.01318, saving model to best_model.h5
# Epoch 16/200
# 11586/11586 [==============================] - 5s 445us/step - loss: 2.8409
#
# Epoch 00016: CRPS_score_val improved from 0.01318 to 0.01312, saving model to best_model.h5
# Epoch 17/200
# 11586/11586 [==============================] - 5s 443us/step - loss: 2.8158
#
# Epoch 00017: CRPS_score_val improved from 0.01312 to 0.01301, saving model to best_model.h5
# Epoch 18/200
# 11586/11586 [==============================] - 5s 447us/step - loss: 2.8000
#
# Epoch 00018: CRPS_score_val improved from 0.01301 to 0.01298, saving model to best_model.h5
# Epoch 19/200
# 11586/11586 [==============================] - 5s 458us/step - loss: 2.7782
#
# Epoch 00019: CRPS_score_val improved from 0.01298 to 0.01293, saving model to best_model.h5
# Epoch 20/200
# 11586/11586 [==============================] - 5s 447us/step - loss: 2.7624
#
# Epoch 00020: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 21/200
# 11586/11586 [==============================] - 5s 448us/step - loss: 2.7481
#
# Epoch 00021: CRPS_score_val did not improve from 0.01291
# Epoch 22/200
# 11586/11586 [==============================] - 5s 448us/step - loss: 2.7358
#
# Epoch 00022: CRPS_score_val improved from 0.01291 to 0.01289, saving model to best_model.h5
# Epoch 23/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.7252
#
# Epoch 00023: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 24/200
# 11586/11586 [==============================] - 5s 449us/step - loss: 2.7275
#
# Epoch 00024: CRPS_score_val did not improve from 0.01288
# Epoch 25/200
# 11586/11586 [==============================] - 5s 445us/step - loss: 2.7195
#
# Epoch 00025: CRPS_score_val improved from 0.01288 to 0.01285, saving model to best_model.h5
# Epoch 26/200
# 11586/11586 [==============================] - 5s 446us/step - loss: 2.7033
#
# Epoch 00026: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 27/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.7045
#
# Epoch 00027: CRPS_score_val did not improve from 0.01285
# Epoch 28/200
# 11586/11586 [==============================] - 5s 460us/step - loss: 2.6935
#
# Epoch 00028: CRPS_score_val did not improve from 0.01285
# Epoch 29/200
# 11586/11586 [==============================] - 5s 451us/step - loss: 2.6981
#
# Epoch 00029: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 30/200
# 11586/11586 [==============================] - 5s 452us/step - loss: 2.6828
#
# Epoch 00030: CRPS_score_val did not improve from 0.01284
# Epoch 31/200
# 11586/11586 [==============================] - 5s 456us/step - loss: 2.6871
#
# Epoch 00031: CRPS_score_val did not improve from 0.01284
# Epoch 32/200
# 11586/11586 [==============================] - 5s 454us/step - loss: 2.6767
#
# Epoch 00032: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 33/200
# 11586/11586 [==============================] - 5s 450us/step - loss: 2.6755
#
# Epoch 00033: CRPS_score_val did not improve from 0.01282
# Epoch 34/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6651
#
# Epoch 00034: CRPS_score_val did not improve from 0.01282
# Epoch 35/200
# 11586/11586 [==============================] - 5s 457us/step - loss: 2.6692
#
# Epoch 00035: CRPS_score_val did not improve from 0.01282
# Epoch 36/200
# 11586/11586 [==============================] - 5s 453us/step - loss: 2.6621
#
# Epoch 00036: CRPS_score_val did not improve from 0.01282
# Epoch 37/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6444
#
# Epoch 00037: CRPS_score_val did not improve from 0.01282
# Epoch 38/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6557
#
# Epoch 00038: CRPS_score_val did not improve from 0.01282
# Epoch 39/200
# 11586/11586 [==============================] - 5s 461us/step - loss: 2.6491
#
# Epoch 00039: CRPS_score_val did not improve from 0.01282
# Epoch 40/200
# 11586/11586 [==============================] - 5s 452us/step - loss: 2.6460
#
# Epoch 00040: CRPS_score_val did not improve from 0.01282
# Epoch 41/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6401
#
# Epoch 00041: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 42/200
# 11586/11586 [==============================] - 5s 454us/step - loss: 2.6371
#
# Epoch 00042: CRPS_score_val did not improve from 0.01282
# Epoch 43/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6300
#
# Epoch 00043: CRPS_score_val did not improve from 0.01282
# Epoch 44/200
# 11586/11586 [==============================] - 5s 456us/step - loss: 2.6321
#
# Epoch 00044: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 45/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6239
#
# Epoch 00045: CRPS_score_val did not improve from 0.01281
# Epoch 46/200
# 11586/11586 [==============================] - 5s 452us/step - loss: 2.6217
#
# Epoch 00046: CRPS_score_val did not improve from 0.01281
# Epoch 47/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.6214
#
# Epoch 00047: CRPS_score_val did not improve from 0.01281
# Epoch 48/200
# 11586/11586 [==============================] - 5s 456us/step - loss: 2.6188
#
# Epoch 00048: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 49/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.6109
#
# Epoch 00049: CRPS_score_val did not improve from 0.01280
# Epoch 50/200
# 11586/11586 [==============================] - 6s 524us/step - loss: 2.6017
#
# Epoch 00050: CRPS_score_val did not improve from 0.01280
# Epoch 51/200
# 11586/11586 [==============================] - 5s 458us/step - loss: 2.6063
#
# Epoch 00051: CRPS_score_val did not improve from 0.01280
# Epoch 52/200
# 11586/11586 [==============================] - 5s 455us/step - loss: 2.6046
#
# Epoch 00052: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 53/200
# 11586/11586 [==============================] - 5s 462us/step - loss: 2.5945
#
# Epoch 00053: CRPS_score_val did not improve from 0.01280
# Epoch 54/200
# 11586/11586 [==============================] - 5s 456us/step - loss: 2.6022
#
# Epoch 00054: CRPS_score_val did not improve from 0.01280
# Epoch 55/200
# 11586/11586 [==============================] - 5s 458us/step - loss: 2.5909
#
# Epoch 00055: CRPS_score_val did not improve from 0.01280
# Epoch 56/200
# 11586/11586 [==============================] - 5s 463us/step - loss: 2.5862
#
# Epoch 00056: CRPS_score_val did not improve from 0.01280
# Epoch 57/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.5841
#
# Epoch 00057: CRPS_score_val did not improve from 0.01280
# Epoch 58/200
# 11586/11586 [==============================] - 5s 464us/step - loss: 2.5788
#
# Epoch 00058: CRPS_score_val did not improve from 0.01280
# Epoch 59/200
# 11586/11586 [==============================] - 5s 457us/step - loss: 2.5765
#
# Epoch 00059: CRPS_score_val did not improve from 0.01280
# Epoch 60/200
# 11586/11586 [==============================] - 5s 460us/step - loss: 2.5648
#
# Epoch 00060: CRPS_score_val did not improve from 0.01280
# Epoch 61/200
# 11586/11586 [==============================] - 5s 456us/step - loss: 2.5649
#
# Epoch 00061: CRPS_score_val did not improve from 0.01280
# Epoch 62/200
# 11586/11586 [==============================] - 5s 459us/step - loss: 2.5644
# Restoring model weights from the end of the best epoch
#
# Epoch 00062: CRPS_score_val did not improve from 0.01280
# Epoch 00062: early stopping
# the 2 fold crps (NN) is 0.012801
# the 2 fold crps (RF) is 0.012933

# %%
crps_oof_nn = []
crps_oof_rf = []

for k in range(loop):
    crps_oof_nn.append(crps_score(oof_nn[k,...], y))
    crps_oof_rf.append(crps_score(oof_rf[k,...], y))

# %%
print("mean crps (NN) is %f"%np.mean(crps_csv_nn))
print("mean crps (RF) is %f"%np.mean(crps_csv_rf))
# Out:
# mean crps (NN) is 0.012833
# mean crps (RF) is 0.012944

# %%
print("mean OOF crps (NN) is %f"%np.mean(crps_oof_nn))
print("mean OOF crps (RF) is %f"%np.mean(crps_oof_rf))
# Out:
# mean OOF crps (NN) is 0.012833
# mean OOF crps (RF) is 0.012943

# %% [markdown]
# ## Blending Weight Optimisation

# %%
def weight_opt(oof_nn, oof_rf, y_true):
    weight_nn = np.inf
    best_crps = np.inf
    
    for i in np.arange(0, 1.01, 0.05):
        crps_blend = np.zeros(oof_nn.shape[0])
        for k in range(oof_nn.shape[0]):
            crps_blend[k] = crps_score(i * oof_nn[k,...] + (1-i) * oof_rf[k,...], y_true)
        if np.mean(crps_blend) < best_crps:
            best_crps = np.mean(crps_blend)
            weight_nn = round(i, 2)
            
        print(str(round(i, 2)) + ' : mean crps (Blend) is ', round(np.mean(crps_blend), 6))
        
    print('-'*36)
    print('Best weight for NN: ', weight_nn)
    print('Best weight for RF: ', round(1-weight_nn, 2))
    print('Best mean crps (Blend): ', round(best_crps, 6))
    
    return weight_nn, round(1-weight_nn, 2)

# %%
weight_nn, weight_rf = weight_opt(oof_nn, oof_rf, y)
# Out:
# 0.0 : mean crps (Blend) is  0.012943
# 0.05 : mean crps (Blend) is  0.012915
# 0.1 : mean crps (Blend) is  0.012889
# 0.15 : mean crps (Blend) is  0.012866
# 0.2 : mean crps (Blend) is  0.012845
# 0.25 : mean crps (Blend) is  0.012826
# 0.3 : mean crps (Blend) is  0.01281
# 0.35 : mean crps (Blend) is  0.012796
# 0.4 : mean crps (Blend) is  0.012785
# 0.45 : mean crps (Blend) is  0.012776
# 0.5 : mean crps (Blend) is  0.012769
# 0.55 : mean crps (Blend) is  0.012765
# 0.6 : mean crps (Blend) is  0.012763
# 0.65 : mean crps (Blend) is  0.012763
# 0.7 : mean crps (Blend) is  0.012766
# 0.75 : mean crps (Blend) is  0.012771
# 0.8 : mean crps (Blend) is  0.012778
# 0.85 : mean crps (Blend) is  0.012788
# 0.9 : mean crps (Blend) is  0.012801
# 0.95 : mean crps (Blend) is  0.012815
# 1.0 : mean crps (Blend) is  0.012833
# ------------------------------------
# Best weight for NN:  0.6
# Best weight for RF:  0.4
# Best mean crps (Blend):  0.012763

# %% [markdown]
# # Time for the actual submission

# %% [markdown]
# ## Define Prediction Function

# %%
def predict(x_te, models_nn, models_rf, weight_nn, weight_rf):
    model_num_nn = len(models_nn)
    model_num_rf = len(models_rf)
    for k,m in enumerate(models_nn):
        if k==0:
            y_pred_nn = m.predict(x_te, batch_size=1024)
            y_pred_rf = models_rf[k].predict(x_te)
        else:
            y_pred_nn += m.predict(x_te, batch_size=1024)
            y_pred_rf += models_rf[k].predict(x_te)
            
    y_pred_nn = y_pred_nn / model_num_nn
    y_pred_rf = y_pred_rf / model_num_rf
    
    return weight_nn * y_pred_nn + weight_rf * y_pred_rf

# %%
# %%time
if  TRAIN_OFFLINE==False:
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()

    for (test_df, sample_prediction_df) in iter_test:
        basetable = create_features(test_df, deploy=True)
        
        basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
        
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable, models_nn, models_rf, weight_nn, weight_rf)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        env.predict(preds_df)

    env.write_submission_file()
# Out:
# ERROR: You must call `predict()` successfully before you can continue with `iter_test()`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# TypeError: 'NoneType' object is not iterable
